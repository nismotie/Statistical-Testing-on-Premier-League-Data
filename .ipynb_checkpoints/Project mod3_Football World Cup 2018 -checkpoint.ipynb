# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %%
teams=pd.read_csv('season-1819_csv.csv')
teams.head()
# Out:
#   Div        Date      HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0  10/08/2018    Man United       Leicester     2     1   H     1     0
# 1  E0  11/08/2018   Bournemouth         Cardiff     2     0   H     1     0
# 2  E0  11/08/2018        Fulham  Crystal Palace     0     2   A     0     1
# 3  E0  11/08/2018  Huddersfield         Chelsea     0     3   A     0     2
# 4  E0  11/08/2018     Newcastle       Tottenham     1     2   A     1     2
#
#   HTR  ... BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
# 0   H  ...     1.79    17  -0.75     1.75     1.70     2.29     2.21  1.55
# 1   H  ...     1.83    20  -0.75     2.20     2.13     1.80     1.75  1.88
# 2   A  ...     1.87    22  -0.25     2.18     2.11     1.81     1.77  2.62
# 3   A  ...     1.84    23   1.00     1.84     1.80     2.13     2.06  7.24
# 4   A  ...     1.81    20   0.25     2.20     2.12     1.80     1.76  4.74
#
#    PSCD  PSCA
# 0  4.07  7.69
# 1  3.61  4.70
# ...

# %%
f = open('player_data.txt')
data = json.load(f)
data
# Out:
# {'success': True,
#  'pager': {'current_page': 1,
#   'max_page': 2,
#   'results_per_page': 500,
#   'total_results': 572},
#  'data': [{'id': 463545,
#    'competition_id': 1625,
#    'full_name': 'David de Gea Quintana',
#    'first_name': 'David',
#    'last_name': 'de Gea Quintana',
#    'known_as': 'David de Gea',
#    'shorthand': 'david-de-gea',
#    'age': 28,
#    'league': 'Premier League',
#    'league_type': 'Domestic League',
#    'season': '2018/2019',
#    'starting_year': 2018,
#    'ending_year': 2019,
#    'url': 'https://footystats.org/players/spain/david-de-gea',
#    'club_team_id': 149,
#    'club_team_2_id': -1,
#    'national_team_id': -1,
#    'position': 'Goalkeeper',
#    'minutes_played_overall': 3420,
#    'minutes_played_home': 1710,
#    'minutes_played_away': 1710,
#    'birthday': 657964800,
#    'nationality': 'Spain',
#    'continent': 'eu',
#    'appearances_overall': 38,
#    'appearances_home': 19,
#    'appearances_away': 19,
# ...

# %%
data.keys()
# Out:
# dict_keys(['success', 'pager', 'data', 'message'])

# %%
df = pd.DataFrame(data['data'])
df.head(3)
# Out:
#    age  appearances_away  appearances_home  appearances_overall  assists_away  \
# 0   28                19                19                   38             0
# 1   29                 1                 4                    6             0
# 2   25                17                12                   30             1
#
#    assists_home  assists_overall  assists_per_90_overall   birthday  \
# 0             0                0                    0.00  657964800
# 1             0                0                    0.00  628588800
# 2             0                1                    0.03  774428400
#
#    cards_overall  ...  rank_in_club_top_scorer  rank_in_league_top_attackers  \
# 0              1  ...                       18                           310
# 1              0  ...                       25                           411
# 2              1  ...                       14                           263
#
#    rank_in_league_top_defenders  rank_in_league_top_midfielders  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'appearances_away', 'appearances_home', 'appearances_overall',
#        'assists_away', 'assists_home', 'assists_overall',
#        'assists_per_90_overall', 'birthday', 'cards_overall',
#        'cards_per_90_overall', 'clean_sheets_away', 'clean_sheets_home',
#        'clean_sheets_overall', 'clean_sheets_per_overall', 'club_team_2_id',
#        'club_team_id', 'competition_id', 'conceded_away', 'conceded_home',
#        'conceded_overall', 'conceded_per_90_overall', 'continent',
#        'ending_year', 'first_name', 'full_name', 'goals_away', 'goals_home',
#        'goals_involved_per_90_overall', 'goals_overall', 'goals_per_90_away',
#        'goals_per_90_home', 'goals_per_90_overall', 'id', 'known_as',
#        'last_match_timestamp', 'last_name', 'league', 'league_type',
#        'min_per_assist_overall', 'min_per_card_overall',
#        'min_per_conceded_overall', 'min_per_goal_overall', 'min_per_match',
# ...

# %%
col=['age', 'min_per_match', 'position', 'goals_overall']
age_minutes = df[col]
age_minutes.head()
age_min=age_minutes.copy()

# %%
age_min['age'].describe()
# Out:
# count    500.000000
# mean      27.162000
# std        4.219403
# min       18.000000
# 25%       24.000000
# 50%       27.000000
# 75%       30.000000
# max       49.000000
# Name: age, dtype: float64

# %%
sample_age=age_min.sample(n=100, random_state=1)
len(sample_age)
# Out:
# 100

# %%
stats.ttest_ind(red_games.goals, no_red_games.goals, equal_var=False)

# %%
sample_age['age_category']=age_min['age'].apply(lambda x: 'old' if x >= 30 else 'young')
age_min.head()
# Out:
#    age  min_per_match    position  goals_overall age_category
# 0   28             90  Goalkeeper              0        young
# 1   29             74    Defender              0        young
# 2   25             87    Defender              1        young
# 3   24             89    Defender              1        young
# 4   25             53    Defender              0        young

# %%
old_players=age_min.loc[age_min['age_category']=='old']
young_players=age_min.loc[age_min['age_category']=='young']
print(len(old_player), len(young_players))
# Out:
# 139 361

# %%
old_players['min_per_match'].plot.hist()

# %%
young_players['min_per_match'].plot.hist()

# %%
old_min=old_players['min_per_match']
young_min=young_players['min_per_match']

# %%
s_old = np.std(old_min, ddof=1)
s_young = np.std(young_min, ddof=1)

# %%
old_x_bar=old_min.mean()
young_x_bar=young_min.mean()

# %%
import scipy.stats as stats
stats.t.importnterval(alpha=0.95, df=len(s_old)-1, old_x_bar, s_old)
# Out:
#   File "<ipython-input-81-09547b202e76>", line 2
#     stats.t.importnterval(alpha=0.95, df=len(s_old)-1, old_x_bar, s_old)
#                                                       ^
# SyntaxError: positional argument follows keyword argument
