# %%
import requests
from dotenv import load_dotenv
load_dotenv()
import os

# %%
import http.client
import json

connection = http.client.HTTPConnection('api.football-data.org')
headers = { 'X-Auth-Token': '3a6d03933d0447719cf4df0d5ddbece3' }
connection.request('GET', '/v2/competitions/PL/matches?season=2018', None, headers )
response = json.loads(connection.getresponse().read().decode())

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(response)
# Out:
# {   'competition': {   'area': {'id': 2072, 'name': 'England'},
#                        'code': 'PL',
#                        'id': 2021,
#                        'lastUpdated': '2019-11-10T17:28:07Z',
#                        'name': 'Premier League',
#                        'plan': 'TIER_ONE'},
#     'count': 380,
#     'filters': {},
#     'matches': [   {   'awayTeam': {'id': 338, 'name': 'Leicester City FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 66, 'name': 'Manchester United FC'},
#                        'id': 233028,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 1,
#                        'referees': [   {   'id': 11610,
#                                            'name': 'Andre Marriner',
#                                            'nationality': None},
#                                        {   'id': 11611,
#                                            'name': 'Scott Ledger',
#                                            'nationality': None},
#                                        {   'id': 11504,
#                                            'name': 'Simon Long',
#                                            'nationality': None},
#                                        {   'id': 11580,
#                                            'name': 'Anthony Taylor',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 1, 'homeTeam': 2},
#                                     'halfTime': {'awayTeam': 0, 'homeTeam': 1},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'HOME_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-10T19:00:00Z'},
#                    {   'awayTeam': {'id': 73, 'name': 'Tottenham Hotspur FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 67, 'name': 'Newcastle United FC'},
#                        'id': 233026,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 1,
#                        'referees': [   {   'id': 11551,
#                                            'name': 'Martin Atkinson',
#                                            'nationality': None},
#                                        {   'id': 11530,
#                                            'name': 'Lee Betts',
#                                            'nationality': None},
#                                        {   'id': 11547,
#                                            'name': 'Stephen Child',
#                                            'nationality': None},
#                                        {   'id': 11520,
#                                            'name': 'Paul Tierney',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 2, 'homeTeam': 1},
#                                     'halfTime': {'awayTeam': 2, 'homeTeam': 1},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'AWAY_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-11T11:30:00Z'},
#                    {   'awayTeam': {'id': 354, 'name': 'Crystal Palace FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 63, 'name': 'Fulham FC'},
#                        'id': 233024,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 1,
#                        'referees': [   {   'id': 11575,
#                                            'name': 'Mike Dean',
#                                            'nationality': None},
#                                        {   'id': 11495,
#                                            'name': 'Ian Hussin',
#                                            'nationality': None},
#                                        {   'id': 11431,
#                                            'name': 'Daniel Robathan',
#                                            'nationality': None},
#                                        {   'id': 11446,
#                                            'name': 'Robert Jones',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 2, 'homeTeam': 0},
#                                     'halfTime': {'awayTeam': 1, 'homeTeam': 0},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'AWAY_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-11T14:00:00Z'},
#                    {   'awayTeam': {'id': 61, 'name': 'Chelsea FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 394, 'name': 'Huddersfield Town AFC'},
#                        'id': 233029,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 1,
#                        'referees': [   {   'id': 11443,
#                                            'name': 'Chris Kavanagh',
#                                            'nationality': None},
#                                        {   'id': 11552,
#                                            'name': 'Peter Kirkup',
#                                            'nationality': None},
#                                        {   'id': 11531,
#                                            'name': 'Marc Perry',
#                                            'nationality': None},
#                                        {   'id': 11605,
#                                            'name': 'Michael Oliver',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 3, 'homeTeam': 0},
#                                     'halfTime': {'awayTeam': 2, 'homeTeam': 0},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'AWAY_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-11T14:00:00Z'},
#                    {   'awayTeam': {   'id': 397,
#                                        'name': 'Brighton & Hove Albion FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 346, 'name': 'Watford FC'},
#                        'id': 233031,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 1,
#                        'referees': [   {   'id': 11567,
#                                            'name': 'Jonathan Moss',
#                                            'nationality': None},
#                                        {   'id': 11480,
#                                            'name': 'Eddie Smart',
#                                            'nationality': None},
#                                        {   'id': 11568,
#                                            'name': 'Andrew Halliday',
#                                            'nationality': None},
#                                        {   'id': 11556,
#                                            'name': 'David Coote',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 0, 'homeTeam': 2},
#                                     'halfTime': {'awayTeam': 0, 'homeTeam': 1},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'HOME_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-11T14:00:00Z'},
#                    {   'awayTeam': {'id': 715, 'name': 'Cardiff City FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 1044, 'name': 'AFC Bournemouth'},
#                        'id': 233032,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 1,
#                        'referees': [   {   'id': 11487,
#                                            'name': 'Kevin Friend',
#                                            'nationality': None},
#                                        {   'id': 11444,
#                                            'name': 'Matthew Wilkes',
#                                            'nationality': None},
#                                        {   'id': 11521,
#                                            'name': 'Mark Scholes',
#                                            'nationality': None},
#                                        {   'id': 11503,
#                                            'name': 'Graham Scott',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 0, 'homeTeam': 2},
#                                     'halfTime': {'awayTeam': 0, 'homeTeam': 1},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'HOME_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-11T14:00:00Z'},
#                    {   'awayTeam': {'id': 62, 'name': 'Everton FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {   'id': 76,
#                                        'name': 'Wolverhampton Wanderers FC'},
#                        'id': 233023,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 1,
#                        'referees': [   {   'id': 11585,
#                                            'name': 'Craig Pawson',
#                                            'nationality': None},
#                                        {   'id': 11586,
#                                            'name': 'Richard West',
#                                            'nationality': None},
#                                        {   'id': 11544,
#                                            'name': 'Simon Beck',
#                                            'nationality': None},
#                                        {   'id': 11430,
#                                            'name': 'Simon Hooper',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 2, 'homeTeam': 2},
#                                     'halfTime': {'awayTeam': 1, 'homeTeam': 1},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'DRAW'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-11T16:30:00Z'},
#                    {   'awayTeam': {'id': 563, 'name': 'West Ham United FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 64, 'name': 'Liverpool FC'},
#                        'id': 233025,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 1,
#                        'referees': [   {   'id': 11580,
#                                            'name': 'Anthony Taylor',
#                                            'nationality': None},
#                                        {   'id': 11581,
#                                            'name': 'Gary Beswick',
#                                            'nationality': None},
#                                        {   'id': 11615,
#                                            'name': 'Adam Nunn',
#                                            'nationality': None},
#                                        {   'id': 11520,
#                                            'name': 'Paul Tierney',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 0, 'homeTeam': 4},
#                                     'halfTime': {'awayTeam': 0, 'homeTeam': 2},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'HOME_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-12T12:30:00Z'},
#                    {   'awayTeam': {'id': 328, 'name': 'Burnley FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 340, 'name': 'Southampton FC'},
#                        'id': 233030,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 1,
#                        'referees': [   {   'id': 11503,
#                                            'name': 'Graham Scott',
#                                            'nationality': None},
#                                        {   'id': 11606,
#                                            'name': 'Constantine Hatzidakis',
#                                            'nationality': None},
#                                        {   'id': 11438,
#                                            'name': 'Dan Cook',
#                                            'nationality': None},
#                                        {   'id': 11436,
#                                            'name': 'Lee Probert',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 0, 'homeTeam': 0},
#                                     'halfTime': {'awayTeam': 0, 'homeTeam': 0},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'DRAW'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-12T12:30:00Z'},
#                    {   'awayTeam': {'id': 65, 'name': 'Manchester City FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 57, 'name': 'Arsenal FC'},
#                        'id': 233027,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 1,
#                        'referees': [   {   'id': 11605,
#                                            'name': 'Michael Oliver',
#                                            'nationality': None},
#                                        {   'id': 11488,
#                                            'name': 'Simon Bennett',
#                                            'nationality': None},
#                                        {   'id': 11564,
#                                            'name': 'Stuart Burt',
#                                            'nationality': None},
#                                        {   'id': 11610,
#                                            'name': 'Andre Marriner',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 2, 'homeTeam': 0},
#                                     'halfTime': {'awayTeam': 1, 'homeTeam': 0},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'AWAY_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-12T15:00:00Z'},
#                    {   'awayTeam': {'id': 67, 'name': 'Newcastle United FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 715, 'name': 'Cardiff City FC'},
#                        'id': 233039,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 2,
#                        'referees': [   {   'id': 11585,
#                                            'name': 'Craig Pawson',
#                                            'nationality': None},
#                                        {   'id': 11480,
#                                            'name': 'Eddie Smart',
#                                            'nationality': None},
#                                        {   'id': 11437,
#                                            'name': 'Andy Garratt',
#                                            'nationality': None},
#                                        {   'id': 11436,
#                                            'name': 'Lee Probert',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 0, 'homeTeam': 0},
#                                     'halfTime': {'awayTeam': 0, 'homeTeam': 0},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'DRAW'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-18T11:30:00Z'},
#                    {   'awayTeam': {'id': 63, 'name': 'Fulham FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 73, 'name': 'Tottenham Hotspur FC'},
#                        'id': 233035,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 2,
#                        'referees': [   {   'id': 11580,
#                                            'name': 'Anthony Taylor',
#                                            'nationality': None},
#                                        {   'id': 11581,
#                                            'name': 'Gary Beswick',
#                                            'nationality': None},
#                                        {   'id': 11615,
#                                            'name': 'Adam Nunn',
#                                            'nationality': None},
#                                        {   'id': 11430,
#                                            'name': 'Simon Hooper',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 1, 'homeTeam': 3},
#                                     'halfTime': {'awayTeam': 0, 'homeTeam': 1},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'HOME_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-18T14:00:00Z'},
#                    {   'awayTeam': {'id': 340, 'name': 'Southampton FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 62, 'name': 'Everton FC'},
#                        'id': 233036,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 2,
#                        'referees': [   {   'id': 11479,
#                                            'name': 'Lee Mason',
#                                            'nationality': None},
#                                        {   'id': 11576,
#                                            'name': 'Darren Cann',
#                                            'nationality': None},
#                                        {   'id': 11505,
#                                            'name': 'Derek Eaton',
#                                            'nationality': None},
#                                        {   'id': 11610,
#                                            'name': 'Andre Marriner',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 1, 'homeTeam': 2},
#                                     'halfTime': {'awayTeam': 0, 'homeTeam': 2},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'HOME_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-18T14:00:00Z'},
#                    {   'awayTeam': {   'id': 76,
#                                        'name': 'Wolverhampton Wanderers FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 338, 'name': 'Leicester City FC'},
#                        'id': 233037,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 2,
#                        'referees': [   {   'id': 11575,
#                                            'name': 'Mike Dean',
#                                            'nationality': None},
#                                        {   'id': 11495,
#                                            'name': 'Ian Hussin',
#                                            'nationality': None},
#                                        {   'id': 11521,
#                                            'name': 'Mark Scholes',
#                                            'nationality': None},
#                                        {   'id': 11503,
#                                            'name': 'Graham Scott',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 0, 'homeTeam': 2},
#                                     'halfTime': {'awayTeam': 0, 'homeTeam': 2},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'HOME_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-18T14:00:00Z'},
#                    {   'awayTeam': {'id': 1044, 'name': 'AFC Bournemouth'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 563, 'name': 'West Ham United FC'},
#                        'id': 233040,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 2,
#                        'referees': [   {   'id': 11494,
#                                            'name': 'Stuart Attwell',
#                                            'nationality': None},
#                                        {   'id': 11570,
#                                            'name': 'Harry Lennard',
#                                            'nationality': None},
#                                        {   'id': 11424,
#                                            'name': 'Neil Davies',
#                                            'nationality': None},
#                                        {   'id': 11487,
#                                            'name': 'Kevin Friend',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 2, 'homeTeam': 1},
#                                     'halfTime': {'awayTeam': 0, 'homeTeam': 1},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'AWAY_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-18T14:00:00Z'},
#                    {   'awayTeam': {'id': 57, 'name': 'Arsenal FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 61, 'name': 'Chelsea FC'},
#                        'id': 233034,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 2,
#                        'referees': [   {   'id': 11551,
#                                            'name': 'Martin Atkinson',
#                                            'nationality': None},
#                                        {   'id': 11530,
#                                            'name': 'Lee Betts',
#                                            'nationality': None},
#                                        {   'id': 11547,
#                                            'name': 'Stephen Child',
#                                            'nationality': None},
#                                        {   'id': 11567,
#                                            'name': 'Jonathan Moss',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 2, 'homeTeam': 3},
#                                     'halfTime': {'awayTeam': 2, 'homeTeam': 2},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'HOME_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-18T16:30:00Z'},
#                    {   'awayTeam': {'id': 394, 'name': 'Huddersfield Town AFC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 65, 'name': 'Manchester City FC'},
#                        'id': 233033,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 2,
#                        'referees': [   {   'id': 11610,
#                                            'name': 'Andre Marriner',
#                                            'nationality': None},
#                                        {   'id': 11504,
#                                            'name': 'Simon Long',
#                                            'nationality': None},
#                                        {   'id': 11586,
#                                            'name': 'Richard West',
#                                            'nationality': None},
#                                        {   'id': 11479,
#                                            'name': 'Lee Mason',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 1, 'homeTeam': 6},
#                                     'halfTime': {'awayTeam': 1, 'homeTeam': 3},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'HOME_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-19T12:30:00Z'},
#                    {   'awayTeam': {'id': 346, 'name': 'Watford FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 328, 'name': 'Burnley FC'},
#                        'id': 233038,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 2,
#                        'referees': [   {   'id': 11520,
#                                            'name': 'Paul Tierney',
#                                            'nationality': None},
#                                        {   'id': 11595,
#                                            'name': 'Adrian Holmes',
#                                            'nationality': None},
#                                        {   'id': 11496,
#                                            'name': 'Mick McDonough',
#                                            'nationality': None},
#                                        {   'id': 11443,
#                                            'name': 'Chris Kavanagh',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 3, 'homeTeam': 1},
#                                     'halfTime': {'awayTeam': 1, 'homeTeam': 1},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'AWAY_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-19T12:30:00Z'},
#                    {   'awayTeam': {'id': 66, 'name': 'Manchester United FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {   'id': 397,
#                                        'name': 'Brighton & Hove Albion FC'},
#                        'id': 233042,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 2,
#                        'referees': [   {   'id': 11487,
#                                            'name': 'Kevin Friend',
#                                            'nationality': None},
#                                        {   'id': 11564,
#                                            'name': 'Stuart Burt',
#                                            'nationality': None},
#                                        {   'id': 11444,
#                                            'name': 'Matthew Wilkes',
#                                            'nationality': None},
#                                        {   'id': 11503,
#                                            'name': 'Graham Scott',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 2, 'homeTeam': 3},
#                                     'halfTime': {'awayTeam': 1, 'homeTeam': 3},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'HOME_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-19T15:00:00Z'},
#                    {   'awayTeam': {'id': 64, 'name': 'Liverpool FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 354, 'name': 'Crystal Palace FC'},
#                        'id': 233041,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 2,
#                        'referees': [   {   'id': 11605,
#                                            'name': 'Michael Oliver',
#                                            'nationality': None},
#                                        {   'id': 11488,
#                                            'name': 'Simon Bennett',
#                                            'nationality': None},
#                                        {   'id': 11611,
#                                            'name': 'Scott Ledger',
#                                            'nationality': None},
#                                        {   'id': 11443,
#                                            'name': 'Chris Kavanagh',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 2, 'homeTeam': 0},
#                                     'halfTime': {'awayTeam': 1, 'homeTeam': 0},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'AWAY_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-20T19:00:00Z'},
#                    {   'awayTeam': {'id': 65, 'name': 'Manchester City FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {   'id': 76,
#                                        'name': 'Wolverhampton Wanderers FC'},
#                        'id': 233043,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 3,
#                        'referees': [   {   'id': 11551,
#                                            'name': 'Martin Atkinson',
#                                            'nationality': None},
#                                        {   'id': 11547,
#                                            'name': 'Stephen Child',
#                                            'nationality': None},
#                                        {   'id': 11606,
#                                            'name': 'Constantine Hatzidakis',
#                                            'nationality': None},
#                                        {   'id': 11494,
#                                            'name': 'Stuart Attwell',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 1, 'homeTeam': 1},
#                                     'halfTime': {'awayTeam': 0, 'homeTeam': 0},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'DRAW'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-25T11:30:00Z'},
#                    {   'awayTeam': {'id': 563, 'name': 'West Ham United FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 57, 'name': 'Arsenal FC'},
#                        'id': 233047,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 3,
#                        'referees': [   {   'id': 11503,
#                                            'name': 'Graham Scott',
#                                            'nationality': None},
#                                        {   'id': 11611,
#                                            'name': 'Scott Ledger',
#                                            'nationality': None},
#                                        {   'id': 11496,
#                                            'name': 'Mick McDonough',
#                                            'nationality': None},
#                                        {   'id': 11487,
#                                            'name': 'Kevin Friend',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 1, 'homeTeam': 3},
#                                     'halfTime': {'awayTeam': 1, 'homeTeam': 1},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'HOME_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-25T14:00:00Z'},
#                    {   'awayTeam': {'id': 715, 'name': 'Cardiff City FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 394, 'name': 'Huddersfield Town AFC'},
#                        'id': 233049,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 3,
#                        'referees': [   {   'id': 11605,
#                                            'name': 'Michael Oliver',
#                                            'nationality': None},
#                                        {   'id': 11488,
#                                            'name': 'Simon Bennett',
#                                            'nationality': None},
#                                        {   'id': 11564,
#                                            'name': 'Stuart Burt',
#                                            'nationality': None},
#                                        {   'id': 11287,
#                                            'name': 'Oliver Langford',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 0, 'homeTeam': 0},
#                                     'halfTime': {'awayTeam': 0, 'homeTeam': 0},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'DRAW'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2018-08-25T14:00:00Z'},
#                    {   'awayTeam': {'id': 338, 'name': 'Leicester City FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 340, 'name': 'Southampton FC'},
#                        'id': 233050,
#                        'lastUpdated': '2019-04-20T15:34:33Z',
#                        'matchday': 3,
#                        'referees': [   {   'id': 11567,
# ...
#                                            'name': 'Scott Ledger',
#                                            'nationality': None},
#                                        {   'id': 11504,
#                                            'name': 'Simon Long',
#                                            'nationality': None},
#                                        {   'id': 11556,
#                                            'name': 'David Coote',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 2, 'homeTeam': 2},
#                                     'halfTime': {'awayTeam': 0, 'homeTeam': 1},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'DRAW'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2019-05-12T14:00:00Z'},
#                    {   'awayTeam': {'id': 715, 'name': 'Cardiff City FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 66, 'name': 'Manchester United FC'},
#                        'id': 233396,
#                        'lastUpdated': '2019-05-12T20:05:31Z',
#                        'matchday': 38,
#                        'referees': [   {   'id': 11567,
#                                            'name': 'Jonathan Moss',
#                                            'nationality': None},
#                                        {   'id': 11531,
#                                            'name': 'Marc Perry',
#                                            'nationality': None},
#                                        {   'id': 11496,
#                                            'name': 'Mick McDonough',
#                                            'nationality': None},
#                                        {   'id': 11430,
#                                            'name': 'Simon Hooper',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 2, 'homeTeam': 0},
#                                     'halfTime': {'awayTeam': 1, 'homeTeam': 0},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'AWAY_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2019-05-12T14:00:00Z'},
#                    {   'awayTeam': {'id': 61, 'name': 'Chelsea FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 338, 'name': 'Leicester City FC'},
#                        'id': 233397,
#                        'lastUpdated': '2019-05-12T20:04:26Z',
#                        'matchday': 38,
#                        'referees': [   {   'id': 11580,
#                                            'name': 'Anthony Taylor',
#                                            'nationality': None},
#                                        {   'id': 11581,
#                                            'name': 'Gary Beswick',
#                                            'nationality': None},
#                                        {   'id': 11576,
#                                            'name': 'Darren Cann',
#                                            'nationality': None},
#                                        {   'id': 11585,
#                                            'name': 'Craig Pawson',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 0, 'homeTeam': 0},
#                                     'halfTime': {'awayTeam': 0, 'homeTeam': 0},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'DRAW'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2019-05-12T14:00:00Z'},
#                    {   'awayTeam': {'id': 57, 'name': 'Arsenal FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 328, 'name': 'Burnley FC'},
#                        'id': 233398,
#                        'lastUpdated': '2019-05-12T20:04:26Z',
#                        'matchday': 38,
#                        'referees': [   {   'id': 11575,
#                                            'name': 'Mike Dean',
#                                            'nationality': None},
#                                        {   'id': 11495,
#                                            'name': 'Ian Hussin',
#                                            'nationality': None},
#                                        {   'id': 11431,
#                                            'name': 'Daniel Robathan',
#                                            'nationality': None},
#                                        {   'id': 11479,
#                                            'name': 'Lee Mason',
#                                            'nationality': None},
#                                        {   'id': 11425,
#                                            'name': 'Nicholas Hopton',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 3, 'homeTeam': 1},
#                                     'halfTime': {'awayTeam': 0, 'homeTeam': 0},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'AWAY_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2019-05-12T14:00:00Z'},
#                    {   'awayTeam': {'id': 394, 'name': 'Huddersfield Town AFC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 340, 'name': 'Southampton FC'},
#                        'id': 233399,
#                        'lastUpdated': '2019-05-12T20:05:31Z',
#                        'matchday': 38,
#                        'referees': [   {   'id': 11436,
#                                            'name': 'Lee Probert',
#                                            'nationality': None},
#                                        {   'id': 11437,
#                                            'name': 'Andy Garratt',
#                                            'nationality': None},
#                                        {   'id': 11521,
#                                            'name': 'Mark Scholes',
#                                            'nationality': None},
#                                        {   'id': 11309,
#                                            'name': 'Peter Bankes',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 1, 'homeTeam': 1},
#                                     'halfTime': {'awayTeam': 0, 'homeTeam': 1},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'DRAW'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2019-05-12T14:00:00Z'},
#                    {   'awayTeam': {'id': 1044, 'name': 'AFC Bournemouth'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 354, 'name': 'Crystal Palace FC'},
#                        'id': 233400,
#                        'lastUpdated': '2019-05-12T20:04:26Z',
#                        'matchday': 38,
#                        'referees': [   {   'id': 11543,
#                                            'name': 'Roger East',
#                                            'nationality': None},
#                                        {   'id': 11570,
#                                            'name': 'Harry Lennard',
#                                            'nationality': None},
#                                        {   'id': 11595,
#                                            'name': 'Adrian Holmes',
#                                            'nationality': None},
#                                        {   'id': 11519,
#                                            'name': 'Keith Stroud',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 3, 'homeTeam': 5},
#                                     'halfTime': {'awayTeam': 1, 'homeTeam': 3},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'HOME_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2019-05-12T14:00:00Z'},
#                    {   'awayTeam': {'id': 65, 'name': 'Manchester City FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {   'id': 397,
#                                        'name': 'Brighton & Hove Albion FC'},
#                        'id': 233401,
#                        'lastUpdated': '2019-05-12T20:04:26Z',
#                        'matchday': 38,
#                        'referees': [   {   'id': 11605,
#                                            'name': 'Michael Oliver',
#                                            'nationality': None},
#                                        {   'id': 11564,
#                                            'name': 'Stuart Burt',
#                                            'nationality': None},
#                                        {   'id': 11488,
#                                            'name': 'Simon Bennett',
#                                            'nationality': None},
#                                        {   'id': 11520,
#                                            'name': 'Paul Tierney',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 4, 'homeTeam': 1},
#                                     'halfTime': {'awayTeam': 2, 'homeTeam': 1},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'AWAY_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2019-05-12T14:00:00Z'},
#                    {   'awayTeam': {'id': 563, 'name': 'West Ham United FC'},
#                        'group': 'Regular Season',
#                        'homeTeam': {'id': 346, 'name': 'Watford FC'},
#                        'id': 233402,
#                        'lastUpdated': '2019-05-12T20:05:45Z',
#                        'matchday': 38,
#                        'referees': [   {   'id': 11443,
#                                            'name': 'Chris Kavanagh',
#                                            'nationality': None},
#                                        {   'id': 11438,
#                                            'name': 'Dan Cook',
#                                            'nationality': None},
#                                        {   'id': 98555,
#                                            'name': None,
#                                            'nationality': None},
#                                        {   'id': 11423,
#                                            'name': 'Andy Madley',
#                                            'nationality': None}],
#                        'score': {   'duration': 'REGULAR',
#                                     'extraTime': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'fullTime': {'awayTeam': 4, 'homeTeam': 1},
#                                     'halfTime': {'awayTeam': 2, 'homeTeam': 0},
#                                     'penalties': {   'awayTeam': None,
#                                                      'homeTeam': None},
#                                     'winner': 'AWAY_TEAM'},
#                        'season': {   'currentMatchday': 38,
#                                      'endDate': '2019-05-12',
#                                      'id': 151,
#                                      'startDate': '2018-08-10'},
#                        'stage': 'REGULAR_SEASON',
#                        'status': 'FINISHED',
#                        'utcDate': '2019-05-12T14:00:00Z'}]}

# %%
response.status_code
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-701672f51b9e> in <module>
# ----> 1 response.status_code
#
# AttributeError: 'dict' object has no attribute 'status_code'

# %%
response.keys()
# Out:
# dict_keys(['count', 'filters', 'competition', 'matches'])

# %%
response['matches'][:1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-142-11d83e185b1c> in <module>
# ----> 1 response['matches'][:1]
#
# KeyError: 'matches'

# %%
response['matches'][0]['homeTeam']['name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-143-1b545575a1e5> in <module>
# ----> 1 response['matches'][0]['homeTeam']['name']
#
# KeyError: 'matches'

# %%
import pandas as pd

df = pd.DataFrame.from_dict(response['matches'])
print(len(df)) #Print how many rows
print(df.columns) #Print column names
df.head() #Previews the first five rows.
# Out:
# 3
# Index(['id', 'competition', 'season', 'utcDate', 'status', 'matchday', 'stage',
#        'group', 'lastUpdated', 'score', 'homeTeam', 'awayTeam', 'referees'],
#       dtype='object')
#        id                             competition  \
# 0  264451  {'id': 2021, 'name': 'Premier League'}
# 1  264456  {'id': 2021, 'name': 'Premier League'}
# 2  264452  {'id': 2021, 'name': 'Premier League'}
#
#                                               season               utcDate  \
# 0  {'id': 468, 'startDate': '2019-08-09', 'endDat...  2019-11-10T14:00:00Z
# 1  {'id': 468, 'startDate': '2019-08-09', 'endDat...  2019-11-10T14:00:00Z
# 2  {'id': 468, 'startDate': '2019-08-09', 'endDat...  2019-11-10T16:30:00Z
#
#      status  matchday           stage           group           lastUpdated  \
# 0  FINISHED        12  REGULAR_SEASON  Regular Season  2019-11-10T19:34:27Z
# 1  FINISHED        12  REGULAR_SEASON  Regular Season  2019-11-10T19:34:27Z
# 2  FINISHED        12  REGULAR_SEASON  Regular Season  2019-11-10T19:34:27Z
#
#                                                score  \
# 0  {'winner': 'HOME_TEAM', 'duration': 'REGULAR',...
# 1  {'winner': 'HOME_TEAM', 'duration': 'REGULAR',...
# 2  {'winner': 'HOME_TEAM', 'duration': 'REGULAR',...
#
#                                            homeTeam  \
# 0  {'id': 76, 'name': 'Wolverhampton Wanderers FC'}
# 1        {'id': 66, 'name': 'Manchester United FC'}
# 2                {'id': 64, 'name': 'Liverpool FC'}
#
#                                            awayTeam  \
# 0              {'id': 58, 'name': 'Aston Villa FC'}
# 1  {'id': 397, 'name': 'Brighton & Hove Albion FC'}
# 2          {'id': 65, 'name': 'Manchester City FC'}
#
#                                             referees
# 0  [{'id': 11580, 'name': 'Anthony Taylor', 'nati...
# 1  [{'id': 11567, 'name': 'Jonathan Moss', 'natio...
# 2  [{'id': 11605, 'name': 'Michael Oliver', 'nati...

# %%
connection = http.client.HTTPConnection('api.football-data.org')
headers = { 'X-Auth-Token': '3a6d03933d0447719cf4df0d5ddbece3' }
connection.request('GET', '/v2/matches?dateFrom=2018-08-01?dateTo=2019-05-30', None, headers )
response = json.loads(connection.getresponse().read().decode())

# %%
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(response)
# Out:
# {   'errorCode': 400,
#     'message': 'Parameter dateFrom must be used in conjunction with dateTo and '
#                'vice versa.'}

# %%
import pandas as pd

df= pd.read_csv('~/Desktop/season-1819_csv.csv')

# %%
df.head()
# Out:
#   Div        Date      HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0  10/08/2018    Man United       Leicester     2     1   H     1     0
# 1  E0  11/08/2018   Bournemouth         Cardiff     2     0   H     1     0
# 2  E0  11/08/2018        Fulham  Crystal Palace     0     2   A     0     1
# 3  E0  11/08/2018  Huddersfield         Chelsea     0     3   A     0     2
# 4  E0  11/08/2018     Newcastle       Tottenham     1     2   A     1     2
#
#   HTR  ... BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
# 0   H  ...     1.79    17  -0.75     1.75     1.70     2.29     2.21  1.55
# 1   H  ...     1.83    20  -0.75     2.20     2.13     1.80     1.75  1.88
# 2   A  ...     1.87    22  -0.25     2.18     2.11     1.81     1.77  2.62
# 3   A  ...     1.84    23   1.00     1.84     1.80     2.13     2.06  7.24
# 4   A  ...     1.81    20   0.25     2.20     2.12     1.80     1.76  4.74
#
#    PSCD  PSCA
# 0  4.07  7.69
# 1  3.61  4.70
# 2  3.38  2.90
# 3  3.95  1.58
# 4  3.53  1.89
#
# [5 rows x 62 columns]

# %%
df.columns
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC',
#        'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD',
#        'BWA', 'IWH', 'IWD', 'IWA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD', 'WHA',
#        'VCH', 'VCD', 'VCA', 'Bb1X2', 'BbMxH', 'BbAvH', 'BbMxD', 'BbAvD',
#        'BbMxA', 'BbAvA', 'BbOU', 'BbMx>2.5', 'BbAv>2.5', 'BbMx<2.5',
#        'BbAv<2.5', 'BbAH', 'BbAHh', 'BbMxAHH', 'BbAvAHH', 'BbMxAHA', 'BbAvAHA',
#        'PSCH', 'PSCD', 'PSCA'],
#       dtype='object')

# %%
f = open('~/Desktop/player_data.txt')
data = json.load(f)
df = pd.DataFrame(data['data'])
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-147-9017cebc5405> in <module>
# ----> 1 f = open('~/Desktop/player_data.txt')
#       2 data = json.load(f)
#       3 df = pd.DataFrame(data['data'])
#       4 df.head()
#
# FileNotFoundError: [Errno 2] No such file or directory: '~/Desktop/player_data.txt'

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [{"success": true,  "pager": {"current_page": 1,  "max_page": 2,  "results_per_page": 500,  "total_results": 572},  "data": [{"id": 463545,  "competition_id": 1625,  "full_name": "David de Gea Quintana",  "first_name": "David",  "last_name": "de Gea Quintana",  "known_as": "David de Gea",  "shorthand": "david-de-gea",  "age": 28,  "league": "Premier League",  "league_type": "Domestic League",  "season": "2018/2019",  "starting_year": 2018,  "ending_year": 2019,  "url": "https://footystats.org/players/spain/david-de-gea",  "club_team_id": 149,  "club_team_2_id": -1,  "national_team_id": -1,  "position": "Goalkeeper",  "minutes_played_overall": 3420,  "minutes_played_home": 1710,  "minutes_played_away": 1710,  "birthday": 657964800,  "nationality": "Spain",  "continent": "eu",  "appearances_overall": 38,  "appearances_home": 19,  "appearances_away": 19,  "goals_overall": 0,  "goals_home": 0,  "goals_away": 0,  "clean_sheets_home": 2,  "clean_sheets_away": 5,  "clean_sheets_overall": 7,  "conceded_overall": 51,  "conceded_home": 23,  "conceded_away": 28,  "assists_overall": 0,  "assists_home": 0,  "assists_away": 0,  "penalty_goals": 0,  "penalty_misses": 0,  "penalty_success": -1,  "goals_involved_per_90_overall": 0,  "assists_per_90_overall": 0,  "goals_per_90_overall": 0,  "clean_sheets_per_overall": 18,  "goals_per_90_home": 0,  "goals_per_90_away": 0,  "min_per_goal_overall": 0,  "conceded_per_90_overall": 1,  "min_per_conceded_overall": 67,  "cards_overall": 1,  "yellow_cards_overall": 1,  "red_cards_overall": 0,  "min_per_match": 90,  "min_per_card_overall": 3420,  "min_per_assist_overall": 0,  "cards_per_90_overall": 0.03,  "rank_in_league_top_attackers": 310,  "rank_in_league_top_midfielders": 419,  "rank_in_league_top_defenders": 90,  "rank_in_club_top_scorer": 18,  "last_match_timestamp": 1557669600},  {"id": 4290,  "competition_id": 1625.1,  "full_name": "Matteo Darmian",  "first_name": "Matteo",  "last_name": "Darmian",  "known_as": "Matteo Darmian",  "shorthand": "matteo-darmian",  "age": 29,  "league": "Premier League".1,  "league_type": "Domestic League".1,  "season": "2018/2019".1,  "starting_year": 2018.1,  "ending_year": 2019.1,  "url": "https://footystats.org/players/italy/matteo-darmian",  "club_team_id": 149.1,  "club_team_2_id": -1.1,  "national_team_id": -1.1,  "position": "Defender",  "minutes_played_overall": 443,  "minutes_played_home": 353,  "minutes_played_away": 90,  "birthday": 628588800,  "nationality": "Italy",  "continent": "eu".1,  "appearances_overall": 6,  "appearances_home": 4,  "appearances_away": 1,  "goals_overall": 0.1,  "goals_home": 0.1,  "goals_away": 0.1,  "clean_sheets_home": 1,  "clean_sheets_away": 0, ...]
# Index: []
#
# [0 rows x 31506 columns]
